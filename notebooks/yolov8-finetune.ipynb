# %%
try:
    import ultralytics
except ImportError:
    # !pip install -U ultralytics --no-deps

# %%
import os
import sys
from IPython.display import FileLink
if not os.path.exists("/kaggle/working/yolov8-realtime-detection"):
    # !git clone https://github.com/LucasAurouet/yolov8-realtime-detection.git
sys.path.append('/kaggle/working/yolov8-realtime-detection/src')
from fine_tune import get_model, finetune

# %%
try:
    model
except NameError:
    model = get_model("yolov8n")

# %%
dataset_path = '/kaggle/input/playing-cards-yolov8/Playing Cards yolov8/data.yaml'
output_path = '/kaggle/working/finetuned_weights.pt'

finetune(model, dataset_path, output_path, epochs=1, res=640)
# Out:
# Ultralytics 8.3.235 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
FileLink('/kaggle/working/finetuned_weights.pt')
# Out:
# /kaggle/working/finetuned_weights.pt

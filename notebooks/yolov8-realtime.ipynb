# %%
try:
    import ultralytics
except ImportError:
    # !pip install -U ultralytics --no-deps

# %%
import os
if not os.path.exists("/kaggle/working/yolov8-realtime-detection"):
    # !git clone https://github.com/LucasAurouet/yolov8-realtime-detection.git
sys.path.append('/kaggle/working/yolov8-realtime-detection/src')
from video_output import read_stream
from ultralytics import YOLO

# %%
model = YOLO("input/yolov8-finetuned/finedtuned_weights.pt")
model.to("cuda")
model.half()

# %%
read_stream(model=None)
